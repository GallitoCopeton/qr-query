# %%
import pymongo as pymongo
import pandas as pd

# %%
clientApp = pymongo.MongoClient('mongodb://findOnlyReadUser:RojutuNHqy@idenmon.zapto.org:888/?authSource=prodLaboratorio')
dbLab = clientApp.prodLaboratorio
resultadosLab = dbLab.joinedLabApp

# %%
codigo = input('Introduzca el codigo del suero para buscar sus aplicaciones')
resultsLab_raw = resultadosLab.find({"CODIGO": codigo})
resultsLab_list = list(resultsLab_raw)
columnasProd = ['CODIGO', 'qr', 'ESAT6_DIAG', 'CFP10_DIAG', 'RV1681_DIAG', 'P24_DIAG']
dfProd = pd.DataFrame(resultsLab_list)
dfProd = dfProd.loc[:, columnasProd]
print(dfProd)
# Out:
# Introduzca el codigo del suero para buscar sus aplicaciones135-VP
#    CODIGO               qr ESAT6_DIAG CFP10_DIAG RV1681_DIAG P24_DIAG
# 0  135-VP  601170500100126          P          P           P        P
# 1  135-VP  601170500100126          P          P           P        P
# 2  135-VP  601170500100126          P          P           P        P
# 3  135-VP  601170500100126          P          P           P        P
# 4  135-VP  601170500100126          P          P           P        P
# 5  135-VP  601170500100126          P          P           P        P

# %% [markdown]
# # NOTA IMPORTANTE:
# ## Celdas bloqueadas para su edición. para desbloquear seguir los siguientes pasos:
#
# ![image.png](attachment:image.png)
#
# y cambiar el parametro de **"editable"** a **true**
#
# ![image.png](attachment:image.png)
