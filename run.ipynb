# %%
# %matplotlib inline
# %run -i "qr_query.py"
# Out:
# Connection to local Mongo successful.
# Connection to Atlas successful.
# No results were found locally, searching in the cloud now.
# No results were found locally, searching in the cloud now.
#       CFP10   Ciudad     ESAT6                Fecha + 5hrs     GP120  \
# 0  Positive  Zapopan  Positive  2018-11-08 16:26:16.672000  Positive
#
#    No. Imagen       P24    RV1681 Validez
# 0         0.0  Positive  Positive   Valid

# %%
import Browser
import pymongo

# %%
URI1 = 'mongodb://findOnlyReadUser:RojutuNHqy@idenmon.zapto.org:888/?authSource=prodLaboratorio'
URI2 = 'mongodb+srv://findOnlyReadUser:RojutuNHqy@clusterfinddemo-lwvvo.mongodb.net/datamap?retryWrites=true'
# Testing
QR = '601170500100387'

CLIENT1 = pymongo.MongoClient(URI1)
DB1 = CLIENT1.prodLaboratorio

# %%
browser = Browser(QR, DB1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6b1a18256126> in <module>
# ----> 1 browser = Browser(QR, DB1)
#
# TypeError: 'module' object is not callable
